# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth7890/Praneeth7890/blob/main/graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,10])
ypoints = np.array([0,500])

plt.scatter(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D","E"])
y = np.array([4,6,8,10,12])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["che","clad","csen1001","csen1011","mat1001","mat1011","mech1021","vdc"])
y = np.array([89,97,95,78,69,59,97,58])

plt.bar(x,y)

plt.xlabel1("subjects")
plt.ylabel1("marks")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4c897e211807> in <module>()
#       7 plt.bar(x,y)
#       8
# ----> 9 plt.xlabel1("subjects")
#      10 plt.ylabel1("marks")
#      11
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabel1'

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
